# %% [markdown]
# # Journal de bord

# %% [markdown]
# ## 📅 Journal de bord – Jour 1 (16/07/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Analyse du sujet.
# - Mise en place du git ainsi que le squelette de projet avec commit initial.
# - Création du notebook avec environnement virtuel fonctionnel (+requirements.txt), import des bibliothèques pour l'EDA et ajout de la traçabilité.
# - Création d'un README à enrichir au fur et à mesure

# %% [markdown]
# ### 📝 Observations / Difficultés
# - Petit dataset : seulement 2500 lignes.
# - Données d'une agence, donc d'un seul bassin d'emploi. Cela peut être un biais en fonction du bassin d'emploi.

# %% [markdown]
# ### ✅ Prochaines étapes
# - Analyse du dataset.
# - EDA du dataset.
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 2 (20/07/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Suite de l'analyse du sujet
# - Suite du notebook avec le `1. Cadrage métier & problème`
# - Début de l'EDA
#
# ### 📝 Observations / Difficultés
# - Plusieurs variables sensibles nécessiteront une attention particulière
#
# ### ✅ Prochaines étapes
# - Suite de l'EDA
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 3 (21/07/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Suite de l'EDA
#
# ### 📝 Observations / Difficultés
# - Des valeurs incohérentes ont été détectées, il va faloir prévoir un traitement.
#
# ### ✅ Prochaines étapes
# - Suite de l'EDA
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 4 (22/07/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Suite de l'EDA
#
# ### 📝 Observations / Difficultés
# - Trouver des représentations qui apportent quelque chose à l'EDA.
#
# ### ✅ Prochaines étapes
# - Suite de l'EDA : DI pour les biais sur les variables sensibles
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 5 (04/08/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Relecture
# - Suite & fin EDA
# - Début de préparation des données
#
# ### 📝 Observations / Difficultés
# - Beaucoup de prétraitements à faire : il ne faudra pas se perdre et penser à tout faire
# - Penser à toutes les demandes dans l'énoncé
#
# ### ✅ Prochaines étapes
# - Suite de la préparation des données
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 6 (05/08/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Suite et fin de la préparation des données en respect des 4 scénarios fournis dans l'énoncé.
# - Début de l'entrainement avec la sélection de 4 modèles les plus adaptés pour le cas d'usage.
#
# ### 📝 Observations / Difficultés
# - Difficulté de respecter la règle d'or pour la comparaison de modèles!
#
# ### ✅ Prochaines étapes
# - Suite de l'entrainement
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 7 (06/08/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Suite de l'entrainement.
#
# ### 📝 Observations / Difficultés
# - Des questionnements sont apparu lors des entrainements sur les hyperparamètres ainsi que sur le test final (1 seul modèle, tous, une première sélection des meilleurs...)
# - Le choix du modèle est compliqué et les résultats sont sous la cible!
#
# ### ✅ Prochaines étapes
# - Relecture et modification surement de certains points sur l'entrainement.
# - Analyse des scénarios et arbitrage.
# - Interprétation pour la communication au client.
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 8 (09/08/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Reprise complète du chapitre 5.5 qui ne va pas. Après recherche dans les cours, sur internet et auprès des LLM, je vais reprendre le chapitre pour arriver à de meilleurs résultats.
# - Utilisation de `class_weight`
# - Recherche d'hyperparam renforçant l'impact sur les résultats au vu des learning curve.
#
# ### 📝 Observations / Difficultés
# - Test de nouveaux paramètres comme `class_weight`.
# - N'étant pas content du résultat final il faut que j'applique lors du test final d'autres modèles et pas seulement le meilleur de l'entrainement. Donc je vais chercher une liste de quelques modèles parmis les meilleurs en entrainement et procéder au test dessus.
# - Peut être qu'il faudra revoir à la baisse la cible définie au début.
#
# ### ✅ Prochaines étapes
# - Evaluation finale des modèles sélectionner et synthès de modélisation.
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 9 (18/08/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Sélection de 3 modèles avec les meilleurs résultats : 2 modèles sélectionnés pour leur précision par rapport à l'erreur critique et un modèle par rapport à son fonctionnement général (F1-macro le meilleur et erreur critique pas trop mauvaise)
# - Réalisation des tests finaux.
# - Reprise de la cible après EDA... en fait après réflexion, au vu de l'EDA, certaine métriques sont dures à baisser car la classe critique est monoritaire, il y a peu de données...
# - Je suis revenu au chapitre 5.6 pour ajouter le calcul de l'inférence pour l'ajouter au tableau 6.1.
#
# ### 📝 Observations / Difficultés
# - Difficulté pour choisir le modèle avec hésitation entre fonctionnement général ou minimisation de l'erreur critique. En posant des hypothèses de côut, ça aide.
# - Mauvaise interprétation de l'EDA pour la révision sur la cible... du coup travail en plus et retour en arrière nécessaire.
#
# ### ✅ Prochaines étapes
# - Analyse des scénarios & arbitrages
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 10 (14/09/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Analyse des scénarios & arbitrages
# - Relecture de l'énoncé pour voir si j'oublie des points avant de passer à l'industrialisation.
# - Ajout de la sauvegarde du pipeline complet (preprocessing + modèle entraîné) ainsi que des métadonnées.
#
# ### 📝 Observations / Difficultés
# - Calculer le "Coût inférence" ! => malheureusement je ne le fais pour tous les scénarios dans le code donc j'ai mis des approximations.
# - Calculer la "Latence p95" ! => malheureusement je ne le fais pas de façon unitaire dans le code, donc j'ai mis des approximations.
# - Après relecture de l'énoncé je me suis aperçu de quelques manques, je dois donc revenir sur ce qui a été fait avec une grosse relecture et l'ajout des points manquants.
# - Ma présentation des critères de succès ne me plait pas, je les ai donc repris.
# - Après relecture je regrette de ne pas avoir plus pousser les tests sur le scénario tabulaire seul, car il aurait pu être prométeur.
#
# ### ✅ Prochaines étapes
# - Interprétation pour la communication client
# - Industrialisation
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 11 (15/09/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Reprise des chapitres 1 à 6 car j'ai remarqué que j'ai mal configuré le scénario 2, en effet il exclus les variables sensibles or j'ai définit que le texte "synthese_entretien" ,'est pas une variable sensible car dans les 9 synthèses différentes il n'y a aucune information sensible.
# - Interprétation pour la communication client
#
# ### 📝 Observations / Difficultés
# - Une petite erreur peut faire perdre pas mal de temps, cf scénario mal configuré qui m'a fait revoir du code et les commentaires, ainsi que la conclusion.
#
# ### ✅ Prochaines étapes
# - Suite de l'interprétation pour la communication client
# - Industrialisation
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 12 (16/09/2026)
#
# ### 🔧 Étapes / Actions réalisées
# - Analyse de l'influence des features pour la décision du modèle sélectionné.
# - Interprétation client de ces points.
# - Début d'industrialisation avec la mise en place des routes `/health`, `/predict`, `train`, testable
#
# ### 📝 Observations / Difficultés
# - Difficulté à démarrer l'inductrialisation, mise en place de l'arborescence des dossiers...
# - Diffculté à imaginer comment tester au fur et à mesure l'avancement de l'industrialisation
#
# Pour le début j'ai pensé installer `uvicorn` pour faire tourner l'application FastAPI (`.\.venv\Scripts\python.exe -m uvicorn app.main:app --reload`).
# `/health` répond ok quand l'API est chargée
# ![health.png](attachment:image.png)
# `/predict` retourne une erreur si une features n'est pas conforme :
# ![predict1.png](attachment:image-2.png)
# sinon retourne la prédiction et les probabilités :
# ![predict2.png](attachment:image-3.png)
#
# ### ✅ Prochaines étapes
# - Suite de l'industrialisation
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 13 (JJ/MM/AAAA)
#
# ### 🔧 Étapes / Actions réalisées
# -
#
# ### 📝 Observations / Difficultés
# -
#
# ### ✅ Prochaines étapes
# -
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 14 (JJ/MM/AAAA)
#
# ### 🔧 Étapes / Actions réalisées
# -
#
# ### 📝 Observations / Difficultés
# -
#
# ### ✅ Prochaines étapes
# -
#
# ---

# %% [markdown]
# ## 📅 Journal de bord – Jour 15 (JJ/MM/AAAA)
#
# ### 🔧 Étapes / Actions réalisées
# -
#
# ### 📝 Observations / Difficultés
# -
#
# ### ✅ Prochaines étapes
# -
#
# ---
